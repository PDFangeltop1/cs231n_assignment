# %% [markdown]
# # Dropout and Data Augmentation
# In this exercise we will implement two ways to reduce overfitting.
#
# Like the previous assignment, we will train ConvNets to recognize the categories in CIFAR-10. However unlike the previous assignment where we used 49,000 images for training, in this exercise we will use just 500 images for training.
#
# If we try to train a high-capacity model like a ConvNet on this small amount of data, we expect to overfit, and end up with a solution that does not generalize. We will see that we can drastically reduce overfitting by using dropout and data augmentation.

# %%
# A bit of setup
import numpy as np
import matplotlib.pyplot as plt
from time import time
from cs231n.layers import *
from cs231n.fast_layers import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load data
# For this exercise our training set will contain 500 images and our validation and test sets will contain 1000 images as usual.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=500, num_validation=1000, num_test=1000, normalize=True):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    if normalize:
        mean_image = np.mean(X_train, axis=0)
        X_train -= mean_image
        X_val -= mean_image
        X_test -= mean_image
    
    # Transpose so that channels come first
    X_train = X_train.transpose(0, 3, 1, 2).copy()
    X_val = X_val.transpose(0, 3, 1, 2).copy()
    X_test = X_test.transpose(0, 3, 1, 2).copy()

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data(num_training=500)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (500, 3, 32, 32)
# Train labels shape:  (500,)
# Validation data shape:  (1000, 3, 32, 32)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3, 32, 32)
# Test labels shape:  (1000,)

# %% [markdown]
# # Overfit
# Now that we've loaded our data, we will attempt to train a three layer convnet on this data. The three layer convnet has the architecture
#
# `conv - relu - pool - affine - relu - affine - softmax`
#
# We will use 32 5x5 filters, and our hidden affine layer will have 128 neurons.
#
# This is a very expressive model given that we have only 500 training samples, so we should expect to massively overfit this dataset, and achieve a training accuracy of nearly 0.9 with a much lower validation accuracy.

# %%
from cs231n.classifiers.convnet import *
from cs231n.classifier_trainer import ClassifierTrainer

model = init_three_layer_convnet(filter_size=5, num_filters=(32, 128))
#print "no maxout "
#best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
#          X_train, y_train, X_val, y_val, model, three_layer_convnet, dropout=None,
#          reg=0.05, learning_rate=0.00005, batch_size=50, num_epochs=30,
#          learning_rate_decay=1.0, update='rmsprop', verbose=True)

#maxout: number of channel
#maxout is initlized in function "init_three_layer_convet, unlike dropout in three_layer_convnet."
trainer = ClassifierTrainer()
model = init_three_layer_convnet(filter_size=5, num_filters=(32, 128),maxout=3)
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train, y_train, X_val, y_val, model, three_layer_convnet, dropout=0.8,maxout=2,
          reg=0.05, learning_rate=0.00005, batch_size=50, num_epochs=3,
          learning_rate_decay=1.0, update='rmsprop', verbose=True)
# Out:
# use maxout activation function!!
# starting iteration  0
# Finished epoch 0 / 3: cost 10.276739, train: 0.140000, val 0.091000, lr 5.000000e-05
# Finished epoch 1 / 3: cost 9.597266, train: 0.400000, val 0.276000, lr 5.000000e-05
# Finished epoch 2 / 3: cost 8.283941, train: 0.492000, val 0.312000, lr 5.000000e-05
# starting iteration  20
# Finished epoch 3 / 3: cost 7.849351, train: 0.550000, val 0.311000, lr 5.000000e-05
# finished optimization. best validation accuracy: 0.312000

# %%
# Visualize the loss and accuracy for our network trained on a small dataset

plt.subplot(2, 1, 1)
plt.plot(train_acc_history)
plt.plot(val_acc_history)
plt.title('accuracy vs time')
plt.legend(['train', 'val'], loc=4)
plt.xlabel('epoch')
plt.ylabel('classification accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss_history)
plt.title('loss vs time')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# # Dropout
# The first way we will reduce overfitting is to use dropout.
#
# Open the file `cs231n/layers.py` and implement the `dropout_forward` and `dropout_backward` functions. We can check the forward pass by looking at the statistics of the outputs in train and test modes, and we can check the backward pass using numerical gradient checking.

# %%
# Check the dropout forward pass

x = np.random.randn(100, 100) 
dropout_param_train = {'p': 0.25, 'mode': 'train'}
dropout_param_test = {'p': 0.25, 'mode': 'test'}


out_train, _ = dropout_forward(x, dropout_param_train)
out_test, _ = dropout_forward(x, dropout_param_test)


# Test dropout training mode; about 25% of the elements should be nonzero
print np.mean(out_train != 0)
# Test dropout test mode; all of the elements should be nonzero
print np.mean(out_test != 0)
# Out:
# 0.2447
# 1.0

# %%
from cs231n.gradient_check import eval_numerical_gradient_array

# Check the dropout backward pass

x = np.random.randn(5, 4)
dout = np.random.randn(*x.shape)
dropout_param = {'p': 0.8, 'mode': 'train', 'seed': 123}

dx_num = eval_numerical_gradient_array(lambda x: dropout_forward(x, dropout_param)[0], x, dout)

_, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
# The error should be around 1e-12
print 'Testing dropout_backward function:'
#print dx_num
#print dx
print 'dx error: ', rel_error(dx_num, dx)

dout = np.random.randn(5,3)
W = np.random.randn(10,4,3)
b = np.random.randn(10,3)
#maxout_param = {'W':W,'b':b}
_, cache = maxout_forward(x, W, b)
dx, dw, db = maxout_backward(dout,cache)
dx_num = eval_numerical_gradient_array(lambda x: maxout_forward(x, W, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: maxout_forward(x, W, b)[0], W, dout)
db_num = eval_numerical_gradient_array(lambda b: maxout_forward(x, W, b)[0], b, dout)

print 'Testing maxout_backward function:'
#print dw[2]
#print dw_num[2]
print 'dx error: ', rel_error(dx_num, dx)
print 'dw error: ', rel_error(dw_num, dw)
print 'db error: ', rel_error(db_num, db)

x = np.random.randn(15,14)
dout = np.random.randn(15,14)
rr = np.random.randn(14)
bb = np.random.randn(14)
_, cache = BatchNormalization_forward(x,rr,bb)
dx, drr, dbb = BatchNormalization_backward(dout,cache)
dx_num = eval_numerical_gradient_array(lambda x: BatchNormalization_forward(x, rr, bb)[0], x, dout)
drr_num = eval_numerical_gradient_array(lambda rr: BatchNormalization_forward(x, rr, bb)[0], rr, dout)
dbb_num = eval_numerical_gradient_array(lambda bb: BatchNormalization_forward(x, rr, bb)[0], bb, dout)

print 'Testing BatchNormalization_backward function:'
print 'dx error: ', rel_error(dx_num, dx)
print 'drr error: ', rel_error(drr_num, drr)
print 'dbb error: ', rel_error(dbb_num, dbb)
# Out:
# Testing dropout_backward function:
# dx error:  7.71640795181e-12
# Testing maxout_backward function:
# dx error:  2.39591711933e-11
# dw error:  1.44573473118e-10
# db error:  5.30156487411e-11
# Testing BatchNormalization_backward function:
# dx error:  1.69052803574e-09
# drr error:  2.10940182275e-11
# dbb error:  8.01648981566e-12

# %% [markdown]
# # Data Augmentation
# The next way we will reduce overfitting is to implement data augmentation. Since we have very little training data, we will use what little training data we have to generate artificial data, and use this artificial data to train our network.
#
# CIFAR-10 images are 32x32, and up until this point we have used the entire image as input to our convnets. Now we will do something different: our convnet will expect a smaller input (say 28x28). Instead of feeding our training images directly to the convnet, at training time we will randomly crop each training image to 28x28, randomly flip half of the training images horizontally, and randomly adjust the contrast and tint of each training image.
#
# Open the file `cs231n/data_augmentation.py` and implement the `random_flips`, `random_crops`, `random_contrast`, and `random_tint` functions. In the same file we have implemented the `fixed_crops` function to get you started. When you are done you can run the cell below to visualize the effects of each type of data augmentation.

# %%
from cs231n.data_augmentation import *

X = get_CIFAR10_data(num_training=100, normalize=False)[0]
num_imgs = 8
print X.dtype
X = X[np.random.randint(100, size=num_imgs)]
                        

X_flip = random_flips(X)
X_rand_crop = random_crops(X, (28, 28))

# To give more dramatic visualizations we use large scales for random contrast
# and tint adjustment.
X_contrast = random_contrast(X, scale=(0.5, 1.0))
X_tint = random_tint(X, scale=(-50, 50))

next_plt = 1
for i in xrange(num_imgs):
    titles = ['original', 'flip', 'rand crop', 'contrast', 'tint']
    for j, XX in enumerate([X, X_flip, X_rand_crop, X_contrast, X_tint]):
        plt.subplot(num_imgs, 5, next_plt)
        img = XX[i].transpose(1, 2, 0)
        if j == 4:
            # For visualization purposes we rescale the pixel values of the
            # tinted images
            low, high = np.min(img), np.max(img)
            img = 255 * (img - low) / (high - low)
        plt.imshow(img.astype('uint8'))
        if i == 0:
            plt.title(titles[j])
        plt.gca().axis('off')
        next_plt += 1
plt.show()
# Out:
# float64

# %% [markdown]
# # Train again
# We will now train a new network with the same training data and the same architecture, but using data augmentation and dropout.
#
# If everything works, you should see a higher validation accuracy than above and a smaller gap between the training accuracy and the validation accuracy.
#
# Networks with dropout usually take a bit longer to train, so we will use more training epochs this time.

# %%
input_shape = (3, 28, 28)
#input_shape = (3,32,32)
def augment_fn(X):
    out = random_flips(random_crops(X, input_shape[1:]))
    out = random_tint(random_contrast(out))
    return out

def predict_fn(X):
    return fixed_crops(X, input_shape[1:], 'center')
    
model = init_three_layer_convnet(filter_size=5, input_shape=input_shape, num_filters=(32, 128),maxout=None,bn=True)
trainer = ClassifierTrainer()

bnRate = 10
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train, y_train, X_val, y_val, model, three_layer_convnet,
          reg=0.05, learning_rate=0.00005*bnRate, learning_rate_decay=1.0,
          batch_size=50, num_epochs=30, update='rmsprop', verbose=True, dropout=None,maxout=None,bn=True,
          augment_fn=augment_fn, predict_fn=predict_fn)
# Out:
# starting iteration  0
# Finished epoch 0 / 30: cost 4.903225, val 0.094000, lr 1.000000e-03
# Finished epoch 1 / 30: cost 2.549339, val 0.165000, lr 1.000000e-03
# Finished epoch 2 / 30: cost 2.625995, val 0.225000, lr 1.000000e-03
# starting iteration  20
# Finished epoch 3 / 30: cost 2.410250, val 0.187000, lr 1.000000e-03
# Finished epoch 4 / 30: cost 2.725661, val 0.278000, lr 1.000000e-03
# starting iteration  40
# Finished epoch 5 / 30: cost 2.633215, val 0.282000, lr 1.000000e-03
# Finished epoch 6 / 30: cost 2.523838, val 0.278000, lr 1.000000e-03
# starting iteration  60
# Finished epoch 7 / 30: cost 2.421874, val 0.274000, lr 1.000000e-03
# Finished epoch 8 / 30: cost 2.755168, val 0.264000, lr 1.000000e-03
# starting iteration  80
# Finished epoch 9 / 30: cost 2.257926, val 0.292000, lr 1.000000e-03
# Finished epoch 10 / 30: cost 2.566768, val 0.307000, lr 1.000000e-03
# starting iteration  100
# Finished epoch 11 / 30: cost 2.588353, val 0.323000, lr 1.000000e-03
# Finished epoch 12 / 30: cost 2.605266, val 0.331000, lr 1.000000e-03
# starting iteration  120
# Finished epoch 13 / 30: cost 2.329813, val 0.317000, lr 1.000000e-03
# Finished epoch 14 / 30: cost 2.592700, val 0.343000, lr 1.000000e-03
# starting iteration  140
# Finished epoch 15 / 30: cost 2.478737, val 0.344000, lr 1.000000e-03
# Finished epoch 16 / 30: cost 2.488608, val 0.329000, lr 1.000000e-03
# starting iteration  160
# Finished epoch 17 / 30: cost 2.408807, val 0.337000, lr 1.000000e-03
# Finished epoch 18 / 30: cost 2.513202, val 0.312000, lr 1.000000e-03
# starting iteration  180
# Finished epoch 19 / 30: cost 2.276880, val 0.371000, lr 1.000000e-03
# Finished epoch 20 / 30: cost 2.276804, val 0.329000, lr 1.000000e-03
# starting iteration  200
# Finished epoch 21 / 30: cost 2.328173, val 0.331000, lr 1.000000e-03
# Finished epoch 22 / 30: cost 2.544917, val 0.346000, lr 1.000000e-03
# starting iteration  220
# Finished epoch 23 / 30: cost 2.368565, val 0.295000, lr 1.000000e-03
# Finished epoch 24 / 30: cost 2.308475, val 0.330000, lr 1.000000e-03
# starting iteration  240
# Finished epoch 25 / 30: cost 2.286149, val 0.330000, lr 1.000000e-03
# Finished epoch 26 / 30: cost 2.076485, val 0.347000, lr 1.000000e-03
# starting iteration  260
# Finished epoch 27 / 30: cost 2.530541, val 0.353000, lr 1.000000e-03
# Finished epoch 28 / 30: cost 2.270823, val 0.332000, lr 1.000000e-03
# starting iteration  280
# Finished epoch 29 / 30: cost 2.243645, val 0.279000, lr 1.000000e-03
# Finished epoch 30 / 30: cost 2.371818, val 0.288000, lr 1.000000e-03
# finished optimization. best validation accuracy: 0.371000

# %%
# Visualize the loss and accuracy for our network trained with dropout and data augmentation.
# You should see less overfitting, and you may also see slightly better performance on the
# validation set.

plt.subplot(2, 1, 1)
#plt.plot(train_acc_history)
plt.plot(val_acc_history)
plt.title('accuracy vs time')
plt.legend(['val', 'train'], loc=4)
plt.xlabel('epoch')
plt.ylabel('classification accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss_history)
plt.title('loss vs time')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()

# %%
model = init_three_layer_convnet(filter_size=5, input_shape=input_shape, num_filters=(32, 128),maxout=None,bn=True)
trainer = ClassifierTrainer()

bnRate = 20
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train, y_train, X_val, y_val, model, three_layer_convnet,
          reg=0.05, learning_rate=0.00005*bnRate, learning_rate_decay=1.0,
          batch_size=50, num_epochs=30, update='rmsprop', verbose=True, dropout=None,maxout=None,bn=True,
          augment_fn=augment_fn, predict_fn=predict_fn)
# Out:
# starting iteration  0
# Finished epoch 0 / 30: cost 4.733479, val 0.124000, lr 1.000000e-03
# Finished epoch 1 / 30: cost 2.776974, val 0.183000, lr 1.000000e-03
# Finished epoch 2 / 30: cost 2.616265, val 0.167000, lr 1.000000e-03
# starting iteration  20
# Finished epoch 3 / 30: cost 2.562665, val 0.242000, lr 1.000000e-03
# Finished epoch 4 / 30: cost 2.593113, val 0.206000, lr 1.000000e-03
# starting iteration  40
# Finished epoch 5 / 30: cost 2.677106, val 0.273000, lr 1.000000e-03
# Finished epoch 6 / 30: cost 2.478721, val 0.247000, lr 1.000000e-03
# starting iteration  60
# Finished epoch 7 / 30: cost 2.597005, val 0.279000, lr 1.000000e-03
# Finished epoch 8 / 30: cost 2.594479, val 0.259000, lr 1.000000e-03
# starting iteration  80
# Finished epoch 9 / 30: cost 2.522757, val 0.321000, lr 1.000000e-03
# Finished epoch 10 / 30: cost 2.534876, val 0.318000, lr 1.000000e-03
# starting iteration  100
# Finished epoch 11 / 30: cost 2.364063, val 0.318000, lr 1.000000e-03
# Finished epoch 12 / 30: cost 2.481690, val 0.316000, lr 1.000000e-03
# starting iteration  120
# Finished epoch 13 / 30: cost 2.455011, val 0.305000, lr 1.000000e-03
# Finished epoch 14 / 30: cost 2.398354, val 0.302000, lr 1.000000e-03
# starting iteration  140
# Finished epoch 15 / 30: cost 2.265158, val 0.338000, lr 1.000000e-03
# Finished epoch 16 / 30: cost 2.382131, val 0.316000, lr 1.000000e-03
# starting iteration  160
# Finished epoch 17 / 30: cost 2.300634, val 0.332000, lr 1.000000e-03
# Finished epoch 18 / 30: cost 2.203993, val 0.359000, lr 1.000000e-03
# starting iteration  180
# Finished epoch 19 / 30: cost 2.322981, val 0.342000, lr 1.000000e-03
# Finished epoch 20 / 30: cost 2.270392, val 0.337000, lr 1.000000e-03
# starting iteration  200
# Finished epoch 21 / 30: cost 2.177951, val 0.338000, lr 1.000000e-03
# Finished epoch 22 / 30: cost 2.042899, val 0.334000, lr 1.000000e-03
# starting iteration  220
# Finished epoch 23 / 30: cost 2.306609, val 0.322000, lr 1.000000e-03
# Finished epoch 24 / 30: cost 2.246764, val 0.346000, lr 1.000000e-03
# starting iteration  240
# Finished epoch 25 / 30: cost 2.143293, val 0.348000, lr 1.000000e-03
# Finished epoch 26 / 30: cost 2.064625, val 0.334000, lr 1.000000e-03
# starting iteration  260
# Finished epoch 27 / 30: cost 2.329115, val 0.315000, lr 1.000000e-03
# Finished epoch 28 / 30: cost 2.020680, val 0.337000, lr 1.000000e-03
# starting iteration  280
# Finished epoch 29 / 30: cost 2.019948, val 0.335000, lr 1.000000e-03
# Finished epoch 30 / 30: cost 2.259017, val 0.330000, lr 1.000000e-03
# finished optimization. best validation accuracy: 0.359000

# %%
plt.subplot(2, 1, 1)
#plt.plot(train_acc_history)
plt.plot(val_acc_history)
plt.title('accuracy vs time')
plt.legend(['val', 'train'], loc=4)
plt.xlabel('epoch')
plt.ylabel('classification accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss_history)
plt.title('loss vs time')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()

# %%
input_shape = (3,32,32)
model = init_three_layer_convnet(filter_size=5, input_shape=input_shape, num_filters=(32, 128),maxout=None,bn=True)
trainer = ClassifierTrainer()
bnRate = 5
bnRegRate = 0.1
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train, y_train, X_val, y_val, model, three_layer_convnet,
          reg=0.05*bnRegRate, learning_rate=0.00005*bnRate, learning_rate_decay=1.0,
          batch_size=50, num_epochs=30, update='rmsprop', verbose=True, dropout=None,maxout=None,bn=True,
          augment_fn=None, predict_fn=None)
# Out:
# starting iteration  0
# Finished epoch 0 / 30: cost 2.840982, val 0.186000, lr 2.500000e-04
# Finished epoch 1 / 30: cost 3.101020, val 0.253000, lr 2.500000e-04
# Finished epoch 2 / 30: cost 2.857481, val 0.302000, lr 2.500000e-04
# starting iteration  20
# Finished epoch 3 / 30: cost 2.843541, val 0.264000, lr 2.500000e-04
# Finished epoch 4 / 30: cost 2.962622, val 0.307000, lr 2.500000e-04
# starting iteration  40
# Finished epoch 5 / 30: cost 2.873308, val 0.300000, lr 2.500000e-04
# Finished epoch 6 / 30: cost 2.586344, val 0.338000, lr 2.500000e-04
# starting iteration  60
# Finished epoch 7 / 30: cost 2.625410, val 0.314000, lr 2.500000e-04
# Finished epoch 8 / 30: cost 2.620786, val 0.321000, lr 2.500000e-04
# starting iteration  80
# Finished epoch 9 / 30: cost 2.462318, val 0.315000, lr 2.500000e-04
# Finished epoch 10 / 30: cost 2.639677, val 0.310000, lr 2.500000e-04
# starting iteration  100
# Finished epoch 11 / 30: cost 2.606584, val 0.336000, lr 2.500000e-04
# Finished epoch 12 / 30: cost 2.546128, val 0.324000, lr 2.500000e-04
# starting iteration  120
# Finished epoch 13 / 30: cost 2.749610, val 0.317000, lr 2.500000e-04
# Finished epoch 14 / 30: cost 2.468903, val 0.311000, lr 2.500000e-04
# starting iteration  140
# Finished epoch 15 / 30: cost 2.476478, val 0.324000, lr 2.500000e-04
# Finished epoch 16 / 30: cost 2.709904, val 0.314000, lr 2.500000e-04
# starting iteration  160
# Finished epoch 17 / 30: cost 2.533100, val 0.304000, lr 2.500000e-04
# Finished epoch 18 / 30: cost 2.850759, val 0.317000, lr 2.500000e-04
# starting iteration  180
# Finished epoch 19 / 30: cost 2.698291, val 0.313000, lr 2.500000e-04
# Finished epoch 20 / 30: cost 2.642730, val 0.303000, lr 2.500000e-04
# starting iteration  200
# Finished epoch 21 / 30: cost 2.493622, val 0.303000, lr 2.500000e-04
# Finished epoch 22 / 30: cost 2.412434, val 0.302000, lr 2.500000e-04
# starting iteration  220
# Finished epoch 23 / 30: cost 2.542521, val 0.297000, lr 2.500000e-04
# Finished epoch 24 / 30: cost 2.651712, val 0.289000, lr 2.500000e-04
# starting iteration  240
# Finished epoch 25 / 30: cost 2.655946, val 0.318000, lr 2.500000e-04
# Finished epoch 26 / 30: cost 2.615332, val 0.308000, lr 2.500000e-04
# starting iteration  260
# Finished epoch 27 / 30: cost 2.674743, val 0.307000, lr 2.500000e-04
# Finished epoch 28 / 30: cost 2.430380, val 0.302000, lr 2.500000e-04
# starting iteration  280
# Finished epoch 29 / 30: cost 2.356930, val 0.301000, lr 2.500000e-04
# Finished epoch 30 / 30: cost 2.292636, val 0.322000, lr 2.500000e-04
# finished optimization. best validation accuracy: 0.338000
